# %% [markdown]
# # Downloading cell metrics as a .csv file
#
# The first step requires downloading of the Allen SDK. If you have not previously downloaded the Allen SDK, please visit http://alleninstitute.github.io/AllenSDK/install.html to read the documentation and download.

# %% [markdown]
# # Select cell search criteria
#
# From the Allen Brain Observatory web interface (http://observatory.brain-map.org/visualcoding/search/cell_list) use the filtering features to select a specific group of cells to analyze further.
#
# Once you have selected cell filter criteria, click the "Use the current filter with the SDK" link (at the bottom left-hand corner of the cell search returns).
#
# Copy and paste the resulting snippet of code into the box below.
#
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# Note: The first time you download the cell specimens it can take some time. Be patient. Once it has been done once, it will be much faster in the future.

# %%
from allensdk.core.brain_observatory_cache import BrainObservatoryCache
import json
          
filter_json = """
[
    {
        "field": "area",
        "op": "in",
        "value": [
            "VISp"
        ]
    },
    {
        "field": "imaging_depth",
        "op": "in",
        "value": [
            175
        ]
    },
    {
        "field": "tld1_name",
        "op": "in",
        "value": [
            "Emx1-IRES-Cre"
        ]
    }
]
"""
       
filters = json.loads(filter_json)
         
boc = BrainObservatoryCache(manifest_file="brain_observatory/manifest.json")
cells = boc.get_cell_specimens(filters=filters)
# Out:
# C:\Users\maxse\Anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %% [markdown]
# Confirm that the number of cells matches the number you had on the website

# %%
len(cells)
# Out:
# 931

# %% [markdown]
# This next step imports the pandas library (http://pandas.pydata.org/), sets your data up in a readable format...

# %%
import pandas as pd
data = pd.DataFrame(cells)

# %% [markdown]
# ...and displays your data for you to view in this notebook

# %%
data
# Out:
#      all_stim  area  cell_specimen_id  \
# 0       False  VISp         540988027
# 1       False  VISp         540988031
# 2       False  VISp         540988044
# 3       False  VISp         540988049
# 4       False  VISp         540988054
# 5       False  VISp         540988059
# 6       False  VISp         540988067
# 7       False  VISp         540988072
# 8       False  VISp         540988081
# 9       False  VISp         540988094
# 10       True  VISp         540988097
# 11       True  VISp         540988102
# 12       True  VISp         540988105
# 13       True  VISp         540988108
# 14       True  VISp         540988111
# 15      False  VISp         540988114
# 16      False  VISp         540988117
# 17       True  VISp         540988120
# 18       True  VISp         540988122
# 19       True  VISp         540988125
# 20      False  VISp         540988130
# 21      False  VISp         540988135
# 22      False  VISp         540988144
# 23      False  VISp         540988149
# 24       True  VISp         540988154
# 25      False  VISp         540988161
# 26      False  VISp         540988166
# 27      False  VISp         540988169
# 28      False  VISp         540988174
# 29      False  VISp         540988179
# ..        ...   ...               ...
# 901     False  VISp         589211481
# 902     False  VISp         589211519
# 903     False  VISp         589211561
# 904     False  VISp         589211601
# 905     False  VISp         589211637
# 906     False  VISp         589211722
# 907     False  VISp         589212180
# 908     False  VISp         589212260
# 909     False  VISp         589212372
# 910     False  VISp         589212430
# 911      True  VISp         589212492
# 912     False  VISp         589212536
# 913      True  VISp         589212584
# 914      True  VISp         589212627
# 915      True  VISp         589212793
# 916      True  VISp         589212820
# 917     False  VISp         589212917
# 918      True  VISp         589212974
# 919      True  VISp         589213127
# 920     False  VISp         589213175
# 921     False  VISp         589213208
# 922     False  VISp         589213249
# 923     False  VISp         589213299
# 924     False  VISp         589213625
# 925     False  VISp         589213648
# 926     False  VISp         589213747
# 927     False  VISp         589213791
# 928     False  VISp         589213873
# 929     False  VISp         589213892
# 930     False  VISp         589213958
#
#                                    donor_full_genotype    dsi_dg  \
# 0    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 1    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 2    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 3    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.576077
# 4    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 5    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 6    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 7    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 8    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 9    Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 10   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.335184
# 11   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.396698
# 12   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.810286
# 13   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.284880
# 14   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 15   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 16   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.926077
# 17   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.201565
# 18   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.879908
# 19   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.566107
# 20   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 21   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 22   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 23   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 24   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 25   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 26   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.229289
# 27   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.304866
# 28   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.828003
# 29   Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.492290
# ..                                                 ...       ...
# 901  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.467331
# 902  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 903  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.539273
# 904  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 905  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.617113
# 906  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.685307
# 907  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.371158
# 908  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 909  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 910  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 911  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.655197
# 912  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.366526
# 913  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 914  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.067294
# 915  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.377506
# 916  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.743144
# 917  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 918  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 919  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.464906
# 920  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.711945
# 921  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.545028
# 922  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.252012
# 923  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.209068
# 924  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  1.197424
# 925  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...  0.811038
# 926  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 927  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 928  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 929  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
# 930  Emx1-IRES-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP...       NaN
#
#      experiment_container_id  failed_experiment_container  g_dsi_dg  g_osi_dg  \
# 0                  517328083                        False       NaN       NaN
# 1                  517328083                        False       NaN       NaN
# 2                  517328083                        False       NaN       NaN
# 3                  517328083                        False  0.586004  0.939233
# 4                  517328083                        False       NaN       NaN
# 5                  517328083                        False       NaN       NaN
# 6                  517328083                        False       NaN       NaN
# 7                  517328083                        False       NaN       NaN
# 8                  517328083                        False       NaN       NaN
# 9                  517328083                        False       NaN       NaN
# 10                 517328083                        False  0.335184  1.000000
# 11                 517328083                        False  0.221066  0.815681
# 12                 517328083                        False  0.552150  0.748815
# 13                 517328083                        False  0.261823  0.619153
# 14                 517328083                        False  0.819843  0.563296
# 15                 517328083                        False       NaN       NaN
# 16                 517328083                        False  0.629900  0.541008
# 17                 517328083                        False  0.194462  0.813747
# 18                 517328083                        False  0.300220  0.589868
# 19                 517328083                        False  0.478861  0.326021
# 20                 517328083                        False  0.670695  0.854293
# 21                 517328083                        False       NaN       NaN
# 22                 517328083                        False  0.397815  0.130663
# 23                 517328083                        False       NaN       NaN
# 24                 517328083                        False  0.320317  0.450342
# 25                 517328083                        False  0.233997  0.552147
# 26                 517328083                        False  0.048530  0.607071
# 27                 517328083                        False  0.304866  1.000000
# 28                 517328083                        False  0.233486  0.152088
# 29                 517328083                        False  0.307985  0.473531
# ..                       ...                          ...       ...       ...
# 901                536323956                        False  0.379682  0.237478
# 902                536323956                        False       NaN       NaN
# 903                536323956                        False  0.464729  0.797371
# 904                536323956                        False       NaN       NaN
# 905                536323956                        False  0.515029  0.707427
# 906                536323956                        False  0.462721  0.062745
# 907                536323956                        False  0.165487  0.165794
# 908                536323956                        False       NaN       NaN
# 909                536323956                        False       NaN       NaN
# 910                536323956                        False       NaN       NaN
# 911                536323956                        False  0.580802  0.946047
# 912                536323956                        False  0.366526  1.000000
# 913                536323956                        False  0.444916  0.602834
# 914                536323956                        False  0.066468  0.908296
# 915                536323956                        False  0.268285  0.497796
# 916                536323956                        False  0.529823  0.379750
# 917                536323956                        False       NaN       NaN
# 918                536323956                        False  0.487124  0.278649
# 919                536323956                        False  0.380267  0.226050
# 920                536323956                        False  0.423704  0.062437
# 921                536323956                        False  0.145952  0.466618
# 922                536323956                        False  0.244166  0.968202
# 923                536323956                        False  0.104540  0.386527
# 924                536323956                        False  0.479740  0.308744
# 925                536323956                        False  0.337937  0.142574
# 926                536323956                        False       NaN       NaN
# 927                536323956                        False       NaN       NaN
# 928                536323956                        False       NaN       NaN
# 929                536323956                        False       NaN       NaN
# 930                536323956                        False       NaN       NaN
#
#      g_osi_sg  ...  specimen_id   tfdi_dg  time_to_peak_ns  time_to_peak_sg  \
# 0    0.678751  ...    509522655       NaN          0.23226              NaN
# 1    0.959401  ...    509522655       NaN          0.26544          0.26544
# 2         NaN  ...    509522655       NaN              NaN              NaN
# 3    0.480496  ...    509522655  0.339791          0.19908          0.29862
# 4    0.942361  ...    509522655       NaN          0.26544          0.29862
# 5         NaN  ...    509522655       NaN              NaN              NaN
# 6         NaN  ...    509522655       NaN              NaN              NaN
# 7         NaN  ...    509522655       NaN              NaN              NaN
# 8    0.895815  ...    509522655       NaN          0.23226          0.19908
# 9    0.924561  ...    509522655       NaN          0.23226          0.36498
# 10   0.914436  ...    509522655  0.451358          0.29862          0.29862
# 11   0.702889  ...    509522655  0.433550          0.23226              NaN
# 12   0.187283  ...    509522655  0.310011          0.29862          0.39816
# 13   0.839287  ...    509522655  0.341993          0.26544          0.23226
# 14   0.668940  ...    509522655  0.228291          0.19908          0.29862
# 15   0.635978  ...    509522655       NaN          0.23226              NaN
# 16        NaN  ...    509522655  0.240604              NaN              NaN
# 17   0.862029  ...    509522655  0.248297          0.29862          0.16590
# 18   0.497197  ...    509522655  0.350441          0.03318              NaN
# 19   0.515170  ...    509522655  0.331031          0.33180          0.13272
# 20        NaN  ...    509522655  0.262551              NaN              NaN
# 21   0.846149  ...    509522655       NaN          0.19908          0.23226
# 22        NaN  ...    509522655  0.319880              NaN              NaN
# 23   0.375221  ...    509522655       NaN          0.16590          0.26544
# 24   0.522355  ...    509522655  0.229558          0.23226          0.29862
# 25        NaN  ...    509522655  0.250070              NaN              NaN
# 26        NaN  ...    509522655  0.284647              NaN              NaN
# 27        NaN  ...    509522655  0.288460              NaN              NaN
# 28        NaN  ...    509522655  0.206185              NaN              NaN
# 29        NaN  ...    509522655  0.215058              NaN              NaN
# ..        ...  ...          ...       ...              ...              ...
# 901  0.781904  ...    524697480  0.410435          0.19908          0.19908
# 902  0.832670  ...    524697480       NaN          0.33180          0.19908
# 903       NaN  ...    524697480  0.264318              NaN              NaN
# 904  0.576256  ...    524697480       NaN          0.16590          0.16590
# 905       NaN  ...    524697480  0.390651              NaN              NaN
# 906       NaN  ...    524697480  0.194002              NaN              NaN
# 907       NaN  ...    524697480  0.311126              NaN              NaN
# 908       NaN  ...    524697480  0.315801              NaN              NaN
# 909  0.723400  ...    524697480       NaN          0.16590          0.23226
# 910  0.619004  ...    524697480       NaN          0.19908          0.19908
# 911  0.399928  ...    524697480  0.254997          0.19908          0.19908
# 912  0.855355  ...    524697480  0.333758          0.19908          0.16590
# 913  0.800678  ...    524697480  0.342393              NaN              NaN
# 914  0.897088  ...    524697480  0.317068          0.23226          0.19908
# 915  0.699699  ...    524697480  0.369792          0.46452          0.16590
# 916  0.933418  ...    524697480  0.293154          0.23226          0.19908
# 917  0.453516  ...    524697480       NaN          0.13272          0.23226
# 918  0.752409  ...    524697480  0.411716          0.23226          0.19908
# 919  0.689397  ...    524697480  0.443664          0.16590          0.23226
# 920  0.125920  ...    524697480  0.449298          0.19908          0.19908
# 921  0.769252  ...    524697480  0.320467          0.39816          0.16590
# 922  0.927699  ...    524697480  0.340168          0.19908          0.19908
# 923  0.622621  ...    524697480  0.321395          0.16590          0.36498
# 924  0.383530  ...    524697480  0.390339          0.16590          0.16590
# 925  0.602062  ...    524697480  0.374143          0.19908          0.19908
# 926  0.566815  ...    524697480       NaN          0.16590          0.19908
# 927       NaN  ...    524697480       NaN              NaN              NaN
# 928       NaN  ...    524697480       NaN              NaN              NaN
# 929       NaN  ...    524697480       NaN              NaN              NaN
# 930       NaN  ...    524697480       NaN              NaN              NaN
#
#        tld1_id      tld1_name    tld2_id   tld2_name    tlr1_id  \
# 0    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 1    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 2    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 3    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 4    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 5    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 6    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 7    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 8    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 9    177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 10   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 11   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 12   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 13   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 14   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 15   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 16   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 17   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 18   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 19   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 20   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 21   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 22   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 23   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 24   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 25   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 26   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 27   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 28   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 29   177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# ..         ...            ...        ...         ...        ...
# 901  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 902  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 903  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 904  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 905  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 906  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 907  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 908  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 909  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 910  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 911  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 912  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 913  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 914  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 915  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 916  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 917  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 918  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 919  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 920  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 921  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 922  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 923  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 924  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 925  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 926  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 927  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 928  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 929  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
# 930  177836119  Emx1-IRES-Cre  177837320  Camk2a-tTA  265943423
#
#               tlr1_name
# 0    Ai93(TITL-GCaMP6f)
# 1    Ai93(TITL-GCaMP6f)
# 2    Ai93(TITL-GCaMP6f)
# 3    Ai93(TITL-GCaMP6f)
# 4    Ai93(TITL-GCaMP6f)
# 5    Ai93(TITL-GCaMP6f)
# 6    Ai93(TITL-GCaMP6f)
# 7    Ai93(TITL-GCaMP6f)
# 8    Ai93(TITL-GCaMP6f)
# 9    Ai93(TITL-GCaMP6f)
# 10   Ai93(TITL-GCaMP6f)
# 11   Ai93(TITL-GCaMP6f)
# 12   Ai93(TITL-GCaMP6f)
# 13   Ai93(TITL-GCaMP6f)
# 14   Ai93(TITL-GCaMP6f)
# 15   Ai93(TITL-GCaMP6f)
# 16   Ai93(TITL-GCaMP6f)
# 17   Ai93(TITL-GCaMP6f)
# 18   Ai93(TITL-GCaMP6f)
# 19   Ai93(TITL-GCaMP6f)
# 20   Ai93(TITL-GCaMP6f)
# 21   Ai93(TITL-GCaMP6f)
# 22   Ai93(TITL-GCaMP6f)
# 23   Ai93(TITL-GCaMP6f)
# 24   Ai93(TITL-GCaMP6f)
# 25   Ai93(TITL-GCaMP6f)
# 26   Ai93(TITL-GCaMP6f)
# 27   Ai93(TITL-GCaMP6f)
# 28   Ai93(TITL-GCaMP6f)
# 29   Ai93(TITL-GCaMP6f)
# ..                  ...
# 901  Ai93(TITL-GCaMP6f)
# 902  Ai93(TITL-GCaMP6f)
# 903  Ai93(TITL-GCaMP6f)
# 904  Ai93(TITL-GCaMP6f)
# 905  Ai93(TITL-GCaMP6f)
# 906  Ai93(TITL-GCaMP6f)
# 907  Ai93(TITL-GCaMP6f)
# 908  Ai93(TITL-GCaMP6f)
# 909  Ai93(TITL-GCaMP6f)
# 910  Ai93(TITL-GCaMP6f)
# 911  Ai93(TITL-GCaMP6f)
# 912  Ai93(TITL-GCaMP6f)
# 913  Ai93(TITL-GCaMP6f)
# 914  Ai93(TITL-GCaMP6f)
# 915  Ai93(TITL-GCaMP6f)
# 916  Ai93(TITL-GCaMP6f)
# 917  Ai93(TITL-GCaMP6f)
# 918  Ai93(TITL-GCaMP6f)
# 919  Ai93(TITL-GCaMP6f)
# 920  Ai93(TITL-GCaMP6f)
# 921  Ai93(TITL-GCaMP6f)
# 922  Ai93(TITL-GCaMP6f)
# 923  Ai93(TITL-GCaMP6f)
# 924  Ai93(TITL-GCaMP6f)
# 925  Ai93(TITL-GCaMP6f)
# 926  Ai93(TITL-GCaMP6f)
# 927  Ai93(TITL-GCaMP6f)
# 928  Ai93(TITL-GCaMP6f)
# 929  Ai93(TITL-GCaMP6f)
# 930  Ai93(TITL-GCaMP6f)
#
# [931 rows x 60 columns]

# %% [markdown]
# And finally creates a file called output.csv that will be located in the same folder that you saved this notebook

# %%
data.to_csv('output.csv')
